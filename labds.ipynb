# %%
import pandas as pd
df = pd.DataFrame({
    'x':[10,20,30,40,50],
     'y':[12,24,33,45,60] })
corr_matrix = df.corr(method='pearson')
print("Pearson correlation Matrix:\n",corr_matrix)
# Out:
# Pearson correlation Matrix:
#            x         y
# x  1.000000  0.996403
# y  0.996403  1.000000

# %%
import pandas as pd
df = pd.DataFrame({
    'x':[10,20,30,40,50],
     'y':[10,20,30,40,50] })
corr_matrix = df.corr(method='pearson')
print("Pearson correlation Matrix:\n",corr_matrix)
# Out:
# Pearson correlation Matrix:
#       x    y
# x  1.0  1.0
# y  1.0  1.0

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\chtejaswin\Downloads\Iris (2).csv")
print(df.corr(method='pearson',numeric_only=float))
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
import pandas as pd
from scipy.stats import spearmanr
df = pd.DataFrame({
    'x':[10,20,30,40,50],
    'y':[12,18,33,47,55]
}) 
corr_val, p_val = spearmanr(df['x'],df['y'])
print(f"Spearman correaltion coefficient:{corr_val}")
print(f"P-Value:{p_val}")
# Out:
# Spearman correaltion coefficient:0.9999999999999999
# P-Value:1.4042654220543602e-24

# %%
import pandas as pd
from scipy.stats import spearmanr
import pandas as pd
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Ethan'],
    'DS': [85, 72, 95, 68, 88],
    'Toc': [90, 80, 88, 74, 91],
    'CD': [78, 85, 92, 70, 84],
    'SOA': [88, 75, 90, 80, 86]
})
print(df.corr(method='pearson',numeric_only=float))
print(df.corr(method='spearman',numeric_only=float))
# Out:
#            DS       Toc        CD       SOA
# DS   1.000000  0.885724  0.717992  0.887656
# Toc  0.885724  1.000000  0.572031  0.764329
# CD   0.717992  0.572031  1.000000  0.336980
# SOA  0.887656  0.764329  0.336980  1.000000
#       DS  Toc   CD  SOA
# DS   1.0  0.7  0.7  0.8
# Toc  0.7  1.0  0.2  0.5
# CD   0.7  0.2  1.0  0.3
# SOA  0.8  0.5  0.3  1.0

# %%
def hamming_distance(str1,str2):
    if len(str1) != len(str2):
        raise ValueError("Strings must be equal length")
    return sum(ch1 != ch2 for ch1, ch2 in zip(str1,str2))
s1 = "karolin"
s2 = "kathrin"
dist = hamming_distance(s1,s2)
print(f"Hamming Distance between '{s1}' and '{s2}':{dist}")
# Out:
# Hamming Distance between 'karolin' and 'kathrin':3

# %%
def jaccard_index(str1, str2):
    set1, set2 = set(str1.split()), set(str2.split())
    inte = set1.intersection(set2)
    uni = set1.union(set2)
    return len(inte) / len(uni)
s1 = "data science is fun"
s2 = "science makes data useful"
print("Jaccard Index:", jaccard_index(s1, s2))
# Out:
# Jaccard Index: 0.3333333333333333

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
s1 = "data science is fun"
s2 = "science makes data useful"
vectorizer = CountVectorizer().fit([s1, s2])
vectors = vectorizer.transform([s1, s2])
cos_sim = cosine_similarity(vectors[0], vectors[1])[0][0]
print("Cosine Similarity:", cos_sim)
# Out:
# Cosine Similarity: 0.5

# %%
def lcs_length(x,y):
    m,n = len(x),len(y)
    dp = [[0]*(n+1) for _ in range(m+1)]
    for i in range(m):
        for j in range(n):
            if x[i] == y[j]:
                dp[i+1][j+1]=dp[i][j]
            else:
                dp[i+1][j+1] = max(dp[i][j+1],dp[i+1][j])
seq1 = "ABCDEF"
seq2 = "AEBDF"
lent = lcs_length(seq1,seq2)
print(f"Longest common Subsequence length between '{seq1}' and '{seq2}':{lent}")
# Out:
# Longest common Subsequence length between 'ABCDEF' and 'AEBDF':None
